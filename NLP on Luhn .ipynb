# %%
import pandas as pd
import json
import numpy as np
import spacy
import nltk
import tqdm  #Shows Progress
import os
import srsly
from spacy import displacy
import gensim
from sklearn.metrics.pairwise import cosine_similarity
from gensim.test.utils import common_texts
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Loading the mapping dictionary file
#Key = ID and Value = resume file name
with open("E:\\Arpitha Swamydas\\Ev Project\\fileId.json") as df:   #fileId file as mapping of id and resume file name
    resumeMap = json.load(df)

# %%
path = "E:/Arpitha Swamydas/Ev Project/all_JSON/"
path
# Out:
# 'E:/Arpitha Swamydas/Ev Project/all_JSON/'

# %%
# Loading resume files in loop
data = dict()   # data is a dict that as the mapping of fileID and their parsed resume
for id_ in tqdm.tqdm(resumeMap):
    try:  
        with open(os.path.join(path, resumeMap[id_]), 'r', encoding = "utf- 8") as f:
            data[id_] = json.load(f)
        id_maps[int(id_)] = int(id_)
    except json.JSONDecodeError:
        print(id_)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 68/68 [00:00<00:00, 152.27it/s]
# 4
# 33
# 51
# 54

# %%
skillset = []   # skill set list 
dataSkills = dict()   #dataSkill dict

# For every id in data, append the skillset list with the Formatted skillname
# and map dataSkills dict i.e. alias = Formatted name

for id_ in tqdm.tqdm(data):  
    for skill in data[id_]['ResumeParserData']["SegregatedSkill"]:
        skillset.append(skill["FormattedName"].strip().lower())
        for alias in skill["Alias"].split(","):
            dataSkills[alias.strip().lower()] = skill["FormattedName"].strip().lower()
            skillset.append(alias.strip().lower())
skillset = set(skillset)   #List to Set
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 1090.12it/s]

# %% [markdown]
# # SPAN RULER for Listing the Skills

# %%
#Writing Pattern File

patterns = []
for alias,skill in dataSkills.items():   #returns key:value as tuple
        patterns.append({"label" : skill , "pattern" : [{"LOWER" :i} for i in alias.split(' ')]})
srsly.write_jsonl('E:\\Arpitha Swamydas\\Ev Project\\patterns.jsonl' , patterns)

# %%
patterns = list(srsly.read_jsonl("patterns.jsonl"))

# %%
nlp_skills = spacy.blank("en")
ruler = nlp_skills.add_pipe("span_ruler")
ruler.add_patterns(patterns)

# %%
def skills(file, nlp=nlp_skills):
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    doc = nlp(data["ResumeParserData"]["DetailResume"])
    return{"skills":[span.text for span in doc.spans["ruler"]]}   #Returns a dict where key = skills and values=span.text(Formatted Names)

# %%
for id_ in data:
    print("\n\n", data[id_]["ResumeParserData"]["Name"]["FullName"], "\n")
    result = skills(os.path.join(path,resumeMap[id_]))
    result = list(sorted({ele for val in result.values() for ele in val}))  #Listing unique values from dictionary
    print(result) #FINAL OUTPUT
# Out:
#  Prasanth Kumar Katta
#
# ['API', 'API Integration', 'API integration', 'Android Architecture Components', 'Core Java', 'GUI', 'Html', 'Kotlin', 'Mobile Programming', 'Model', 'Programming Skills', 'Quick learner', 'Real Time Database', 'Technical Skills', 'UI', 'View', 'Visual Studio', 'Web Services', 'adaptable', 'responsive design', 'version control tools']
#
#
#  Imran Iqbal Shaikh
#
# ['Agile', 'Agile Scrum', 'Agile Scrum framework', 'Angular', 'B2B', 'C', 'CSS', 'CXM', 'Case Management', 'Coaching', 'Code reviews', 'Confluence', 'DevOps', 'Dynamics 365', 'HTML', 'Image editing software', 'JSON', 'Meeting Scheduling', 'Performance evaluation', 'Planning', 'Programming Languages', 'Proof of Concepts', 'QA', 'Scrum', 'Scrum framework', 'View', 'VoIP', 'Web Services', 'app development', 'code base', 'code reviews', 'control tests', 'iOS app development', 'macOS', 'management application', 'project objectives', 'requirement gathering', 'system development']
#
#
#  Muralidhara V
#
# ['2003 Server', 'Application Support', 'Backup and restore', 'DHCP', 'DNS', 'Exchange Mail', 'Exchange Mail Server', 'Exchange server', 'IDS', 'IT infrastructure', 'IT service', 'IT system', 'Installation and Configuration', 'LAN', 'LAN technologies', 'MS Exchange', 'MS Exchange server', 'MS Outlook', 'Moss 2007', 'NAS', 'Network', 'OS', 'Office365', 'Planning', 'Symantec', 'System administration', 'Thunderbird', 'Trouble Shooting', 'VSS', 'Vendor Coordination', 'WAN', 'WSUS', 'WSUS server', 'Win 2003', 'Win 2003 Server', 'Windows 2003', 'Windows server 2012', 'active monitoring', 'company policies', 'development teams', 'disaster recovery operations', 'domain controllers', 'equipment procurement', 'hMail Server', 'maintenance activities', 'planning', 'test environments', 'web servers', 'web services']
#
#
#  GANGADHARAIAH N
#
# ['C']
#
#
#  Ankitha S
#
# ['CORE JAVA', 'DML', 'DQL', 'File Handling', 'Motivated', 'RDBMS', 'RDBMS Concepts', 'SDLC', 'SQL Queries', 'Test Plans', 'Test Scenarios', 'friendly', 'innovative', 'problem solving skills', 'solving skills', 'technical skills']
#
#
#  Neeraj Tiwari
#
# ['API', 'Apache Server', 'Apache server', 'Azure', 'Azure Cloud', 'Banking', 'CSS', 'Data Structures', 'Decision Support', 'Developer studio', 'Flexibility', 'Front End', 'HTML', 'IBM websphere server', 'Information Technology', 'Information technology', 'Intellij', 'J2EE', 'J2EE application', 'JAVA Technology', 'JBoss', 'JDBC', 'JPA', 'JSP', 'Java Development', 'Java Script', 'Jboss', 'Jboss Server', 'Leadership ability', 'Listening', 'MVC', 'MVC pattern', 'Primary skill', 'Sql Server', 'UI', 'Web Designing', 'Web Services', 'Web services', 'banking', 'developer studio', 'end implementation', 'java technology', 'jboss', 'jboss Server', 'result oriented', 'secondary skill', 'web services', 'websphere', 'websphere server']
#
#
#  Aneesh Unnitten
#
# ['Asp', 'Banking', 'C', 'CRM', 'Communicate effectively', 'Crystal Report', 'DB Design', 'DFD', 'DMS', 'Dynamics CRM', 'Dynamics CRM 4.0', 'ERP', 'ERP software', 'Finance Resource Management', 'GUI', 'Human Resource', 'Information Technology', 'Inventory System', 'MIS', 'MIS reports', 'MS ACCESS', 'MS Access', 'MS CRM', 'MS Dynamics', 'MS Dynamics CRM', 'MVC', 'Management System', 'Microsoft Dynamics CRM', 'Microsoft Dynamics CRM 4.0', 'Mobile Banking', 'OS', 'Purchase Management', 'RDBMS', 'Report Development', 'Reporting Tool', 'Reports development', 'Requirement Analysis', 'Requirement gathering', 'SQL Server', 'SQL Server 2005', 'SQL Server 2012', 'SQL Server Reporting', 'SQL Server reporting', 'SSRS', 'TSQL', 'Technical Skills', 'VB', 'VB 6', 'VB 6.0', 'VB.NET', 'Visual Studio', 'Visual Studio 2013', 'WCF', 'WPF', 'Webservices', 'Win Forms', 'WinForms', 'business processes', 'coaching', 'communicate effectively', 'customer relationship', 'customer service processes', 'development and maintenance', 'development lifecycle', 'effective communicator', 'management Software', 'managing technical', 'planning', 'relationship management', 'solving skills', 'training manuals', 'view']
#
#
#  MANIK GUPTA
#
# ['API', 'Angular', 'Angular 7', 'Bootstrap 4', 'CSS', 'CSS 3', 'Cassandra', 'E-Commerce', 'FRONT END', 'Ionic Framework', 'Kafka', 'License Management', 'MEAN Stack', 'Microservice Architecture', 'NodeJS', 'POC', 'REST API', 'Responsible for designing', 'Slack', 'UI', 'UX', 'communicating', 'communications', 'development team', 'end implementation', 'front end', 'new technologies', 'stock management']
#
#
#  Manish Kumar
#
# ['Android Mobile Application', 'Android SDK', 'Inventory Management System', 'JSON', 'Kotlin', 'MVP', 'Mac OS', 'Management System', 'Mobile App', 'OS', 'Optimistic', 'React Js', 'SDLC', 'UAT', 'UI', 'VS Code', 'Web Services', 'adapt quickly', 'coding conventions', 'kotlin', 'working independently']
#
#
#  Vivek K
#
# ['App analytics', 'Automation tools', 'Banking', 'C', 'CI', 'Ecommerce', 'Health care', 'Hybrid apps', 'IOT', 'Jenkins CI', 'Kotlin', 'Mobile app', 'Node JS', 'Objective C', 'User Monitoring', 'app Analytics', 'communications', 'iOS Mobile application development', 'mobile apps']
#
#
#  Nagarjuna G. M
#
# ['ASP', 'ASP.NET Framework', 'Azure', 'C', 'CSS', 'Customer Care', 'Enterprise Applications', 'Fetal monitoring', 'HTML', 'MVC', 'Operating Systems', 'Operating Systems : Windows', 'Programming Languages', 'SQL Server', 'SQL Server 2008', 'SSRS', 'SSRS Reporting', 'SSRS Reports', 'Sql Server', 'Sql Server 2008', 'Sql server', 'Sql server 2008', 'Stored Procedures', 'TFS', 'Technical Skills', 'Vendor Audits', 'WCF', 'WCF Services', 'Web Services', 'Web Technologies', 'Web based application', 'WebAPI', 'WebApi', 'Windows Azure', 'full life cycle', 'reduce costs', 'software development process', 'supply chain', 'view', 'web based application']
#
#
#  SUDHEER TANGELLAPELLY
#
# ['API', 'AWS', 'Agile', 'Agile methodology', 'CSS', 'DevOps', 'Develop new technologies', 'Digital Advertising', 'Docker', 'EC2', 'Flask', 'Good communication', 'HTML', 'House development', 'Hybrid App', 'Information Technology', 'Micro Services', 'Mobile development', 'Motivated', 'Nodejs', 'Planning', 'QA', 'Requirement analysis', 'Requirement analysis and design', 'SDLC', 'SOP', 'Self Motivated', 'Test applications', 'Troubleshoot', 'UAT', 'UAT Management', 'Willingness to learn', 'adaptable', 'automation framework', 'campaign launch', 'client servicing', 'coaching', 'communication skills', 'creative', 'development team', 'ec2', 'integration architecture', 'internal processes', 'mobile applications', 'new technologies', 'presentations', 'systems integration', 'technical expertise', 'troubleshoot']
#
#
#  Shubham Kumar
#
# ['.NET Web API', 'API', 'Angular', 'Angular 9', 'C', 'CSS', 'Confluence', 'Crucible', 'HTML', 'MS SQL', 'MS SQL Server', 'POC', 'SQL Server', 'SVN', 'TFS', 'UI', 'VS Code', 'Visual Studio', 'Web Applications', 'agile', 'agile methodology', 'clinical reports', 'developing Web', 'developing Web Applications']
#
#
#  Shubham Bhosle
#
# ['API', 'Ability to learn', 'Angular', 'Angular 7', 'CSS', 'Core JAVA', 'Core Java', 'DOCKER', 'Docker', 'HTML', 'J2EE', 'JAVA 8', 'JPA', 'Java 8', 'Java SE', 'Java SE 6', 'MAVEN', 'MVC', 'Maven', 'Microservice Architecture', 'Oriented Programming', 'Programming concepts', 'REST API', 'SDLC', 'Test-Driven Development', 'Tomcat', 'UAT', 'UI', 'View', 'Web Services', 'Webservices', 'change requests', 'core java', 'enterprise application', 'information Technology', 'information technology', 'information technology and services', 'web servers']
#
#
#  Shabbir Ahmed
#
# ['API', 'Access 2000', 'Angular', 'Angular JS', 'Angular js', 'App Server', 'Arduino', 'Arduino IDE', 'Azure', 'C', 'CSS', 'Crystal Reports', 'Crystal Reports 8.5', 'Database designing', 'DevOps', 'Developing web', 'Developing web Applications', 'Devops', 'Examination', 'Excel', 'Flexibility', 'Front end', 'Generate Reports', 'HTML', 'HTML5', 'IIS', 'IIS 6.0', 'IOT', 'MS SQL', 'MVC', 'Personal Skills', 'Quick learner', 'Reporting tool', 'Requirement analysis', 'Requirement gathering', 'Rest API', 'SQL Server', 'SQL Server 2008', 'SSRS', 'SVN', 'Strong interpersonal skills', 'TFS', 'Version Control Tools', 'Visual Studio', 'WMS', 'Web Technologies', 'WebAPI', 'Windows server 2012', 'stored procedures', 'view', 'web Applications']
#
#
#  KAVETI SASIDEEP
#
# ['API', 'Agile', 'Agile Development', 'Agile Development Methodologies', 'Angular', 'Azure', 'Azure DevOps', 'Banking', 'C', 'Change Requests', 'Code reviews', 'DevOps', 'MS SQL', 'MS SQL Server', 'MS SQL Server 2008', 'MVC', 'Network', 'OOPS', 'Operating Systems', 'Operating Systems : Windows', 'SQL Server', 'SQL Server 2008', 'Scripting Languages', 'TFS', 'Team Foundation Server', 'User interfaces', 'Visual Studio', 'WebAPI', 'c', 'developing web', 'developing web applications', 'web applications']
#
#
#  ABHINAV PANDEY
#
# ['.NET 1.1', '.NET 2.0', '.NET Framework', 'ADO .NET', 'API', 'ASP', 'ASP .NET', 'ASP .NET 1.1', 'C', 'CSS', 'Database : SQL', 'Desktop applications', 'DevExpress', 'Examination', 'HTML', 'Information Systems', 'MS Office', 'MS Visio', 'MVC', 'Management Information', 'Management Information Systems', 'OOP', 'Object Oriented', 'Office operations', 'OpenSpan', 'Operating Systems', 'Operating Systems : Windows', 'Oracle 11', 'Oriented Programming', 'PTP', 'QlikView', 'RDBMS', 'REST API', 'Reporting Tool', 'SDLC', 'SDLC methodologies', 'SQL Server', 'SQL Server 2008', 'SVN', 'Subversion', 'T-SQL', 'Tortoise SVN', 'TypeMock', 'UI', 'VB', 'VB .Net', 'Visio', 'Visual Source Safe', 'Visual Studio', 'WCF', 'WCF Services', 'WCF services', 'WPF', 'Web Applications', 'Web Technologies', 'Winforms', 'Working independently', 'XSD', 'XSL', 'agile', 'code reviews', 'excel', 'front end', 'information management', 'planning', 'point of contact', 'software solutions', 'stored procedures', 'technical documents', 'user interfaces', 'web services']
#
#
#  RAGHURAM M
#
# ['ASP', 'ASP.Net 2.0', 'ASP.Net 3.5', 'ASP.net framework', 'Access 2000', 'Business Systems', 'C', 'Classic ASP', 'Dot net', 'Electronic System', 'Excel', 'Front End', 'HTML', 'MIS', 'MIS reports', 'MS SQL', 'MS SQL Server', 'MVC', 'MVC architecture', 'Management System', 'Management of Raw materials', 'Power System', 'Power Systems', 'Programming Languages', 'SQL Server', 'SQL Server 2005', 'SQL Server 2008', 'Sales Order Management', 'Unix', 'VB', 'VB.Net', 'VB.net', 'Visual Studio', 'Visual Studio 2008', 'WCF', 'computer programming', 'front end', 'insurance policies', 'programming languages', 'web based application']
#
#
#  S. BALASUBRAMANIAN
#
# ['Android SDK', 'Android Sdk', 'Application maintenance and support', 'Core Java', 'Development Tools', 'ERP', 'Kotlin', 'MVP', 'Mobile Development', 'OData', 'SAP', 'TECHNICAL COMPETENCIES', 'UI', 'barcode scanning', 'google map', 'health care', 'kotlin', 'maintenance and support', 'sales plan']
#
#
#  SHEETHAL KUMAR S. M
#
# ['.NET 3.5', '.net Technologies', 'API', 'ASP', 'ASP .Net', 'ASP.NET 3.5', 'Analysis Software', 'Asp', 'C', 'CNC', 'CRM', 'CSS', 'Crystal Report', 'DBMS', 'Database connectivity', 'Design and Development', 'ERP', 'Excel', 'Finance Application', 'Gauge Management', 'HMI', 'HTML', 'HTML4', 'HTML5', 'IIS7', 'Image Acquisition', 'Image Processing', 'JSON', 'MS ACCESS', 'MS Access', 'MS Excel', 'MS SQL', 'MS SQL Server', 'MS SQL Server 2008', 'MS SQL Server 2008 R2', 'Manufacturing Process', 'Microsoft .NET', 'Microsoft .NET 3.5', 'Microsoft .net', 'Microsoft .net Technologies', 'Operating Systems', 'Operating Systems : Windows', 'PLC', 'QC', 'Quality Testing', 'Requirement Specifications', 'SAP', 'SQL Server', 'SQL Server 2005', 'SQL Server 2008', 'SQL Server 2008 R2', 'SQL Server 2008R2', 'SQLSERVER', 'SRS', 'SSIS', 'SSIS packages', 'Server 2008 R2', 'Source Control', 'Stored Procedures', 'System Requirement', 'Technical Skills', 'VAT', 'VB6', 'VS 2010', 'VSS', 'View', 'Visual Studio', 'Visual Studio 2008', 'WIN CE', 'WINCE', 'Web Services', 'c', 'computer vision', 'design and development', 'maintain Inventory', 'online sales']
#
#
#  CHANDAN
#
# ['.NET MVC', '.Net technologies', 'ADO .Net', 'API', 'ASP', 'Angular', 'Angular JS', 'Angular js', 'Azure', 'BI Tool', 'C', 'CSS', 'Customer relationship', 'DB Architecture', 'ERP', 'ERP system', 'Front End', 'HTML', 'HTML5', 'Java script', 'MVC', 'MYSQL Server', 'RFID', 'SQL Server', 'SQL server', 'SSRS', 'Supply chain', 'WCF', 'WCF services', 'WMS', 'accept challenges', 'business reports', 'chain management', 'contract manufacturing', 'dedicated', 'electronic medical record', 'friendly', 'front end', 'mobile app', 'operational control', 'relationship management']
#
#
#  ANITHA T
#
# ['C', 'Examination', 'GSM', 'NETWORK', 'Willingness to learn', 'adaptable', 'development program', 'personal skills', 'power distribution']
#
#
#  Sagar Chandra Pradhan
#
# ['ADO .NET', 'API', 'ASP.NET MVC 4', 'ASP.Net MVC 4.0', 'Able to communicate', 'C', 'CSS', 'Database designing', 'Design Pattern', 'ERP', 'HTML', 'HTML5', 'LINQ', 'MSSQL', 'MSSQL Server', 'MVC', 'MVC 4', 'My SQL', 'OOP', 'Operating Systems', 'Party management', 'SQL Server', 'SQL Server 2008R2', 'SRS', 'SSIS', 'SSRS', 'Software Solution', 'Technical Skills', 'UI', 'WCF', 'WPF', 'Web services', 'Winforms', 'adaptable', 'analytical skills', 'design & development', 'developing web', 'developing web applications', 'interact with clients', 'meet deadlines', 'object oriented', 'problem solver', 'problem solving skills', 'productive', 'quick learner', 'solving skills', 'stored procedures', 'use cases', 'web applications']
#
#
#  PRASHOBH T. K
#
# ['API', 'AWS', 'Agile', 'Agile SCRUM', 'Agile SCRUM methodology', 'Angular', 'Angular 5', 'C', 'CSS', 'CSS 2.0', 'Crystal Reports', 'Crystal reports', 'Database performance tuning', 'Development Department', 'ERP', 'ERP software', 'Effective communication Skills', 'GSM', 'Gsm', 'HTML', 'IIS', 'IIS 7.0', 'JSON', 'Life Cycle Management', 'MS SQL', 'MSSQL', 'MVC', 'Microsoft TFS', 'Microsoft VSS', 'Model', 'Ms SQL', 'Mvc', 'MySQL 5.0', 'MySQL server', 'Operating Systems', 'Project Goals', 'RDBMS', 'Reporting Tools', 'SCRUM', 'SQL Queries', 'SQL Server', 'SQL Server 2005', 'SQL server', 'SVN', 'Software Application', 'Stored Procedures', 'Systems Analysis', 'TFS', 'Technical Skills', 'Testcases', 'UI', 'VSS', 'Vb', 'Vb 6.0', 'Vb.net', 'Version Control Tools', 'View', 'Visual Basic .net', 'Visual Studio', 'WCF', 'WCF service', 'Web Services', 'WebAPI', 'angular', 'communication Skills', 'excellent communication', 'generate reports', 'generating Reports', 'html', 'improve performance', 'lifecycle development', 'mvc', 'mysql 5.5', 'object oriented', 'online sales', 'performance optimization', 'relational database', 'stored procedures', 'unit test', 'vb.net', 'web applications', 'webservices', 'windows services', 'work ethics']
#
#
#  MANOJ CR
#
# ['C', 'CSS', 'Cyber Security', 'Dedicated', 'HTML', 'Health Care', 'Health Care Management', 'Willing to learn new', 'Willing to learn new things']
#
#
#  VIGNESH N B. E
#
# ['API', 'Android SDK', 'Angular', 'Angular 8', 'Augmented Reality', 'CSS', 'Content Management Systems', 'Customer Relationship', 'ERP', 'Excel', 'GUI', 'HTML', 'HTML 5', 'Human Resources', 'Hybrid Mobile Application', 'Hybrid Mobile Application development', 'Interactive Technologies', 'Ionic 3', 'J2EE', 'JDBC', 'JPA', 'JPQL', 'JSF', 'Jasper', 'Jasper Reports', 'MVC', 'MVC Architectural Pattern', 'MySql 5', 'NodeJs', 'OOP', 'Object Oriented', 'Object Oriented Development', 'Oriented Development OOP', 'Performed Unit Testing', 'Relationship Management', 'Requirement Gathering', 'SVN', 'Sage ERP', 'Technical skills', 'Tomcat', 'Tomcat 6.0', 'TopLink', 'UI', 'VS Code', 'Xhtml', 'development and maintenance', 'innovative']
#
#
#  Xpress JS
#
# ['.NET Core 2.0', '.NET Core 2.2', 'API', 'Angular', 'Angular 2', 'Angular 4', 'Angular 7', 'Angular JS', 'Application Servers', 'Azure', 'Azure Cloud', 'BackboneJS', 'Bot Framework', 'C', 'CMS', 'CSS', 'CSS 3', 'CosmosDB', 'Crystal Reports', 'Docker', 'Ember', 'Express JS', 'HTML', 'HTML 5', 'Innovative', 'JSON', 'MS SQL', 'MS SQL Server', 'MS SQL Server 2012', 'MVC', 'Microsoft Azure Infrastructure', 'NodeJS', 'Office 365', 'Oracle 10', 'Programming languages', 'SQL Server', 'SQL Server 2012', 'Solution design', 'Solution design and development', 'Technical Expertise', 'Technical Skills', 'VB.NET', 'VB6', 'Visual Studio', 'WCF', 'WCF 4.5', 'WPF', 'Web API 2', 'Web Applications', 'Web Technologies', 'Windows 10', 'design and development', 'development tools', 'web technologies']
#
#
#  SANDEEP SARAN BOSE
#
# ['.NET 4.0', '.NET 4.5', '.NET Core 2.1', '.Net Core 2.1', 'API', 'ASP.NET MVC4', 'ASP.NET MVC5', 'Agile', 'Angular', 'Angular 7', 'Angular JS', 'Application Servers', 'Applications Development', 'C', 'Database : SQL', 'Development Lifecycle', 'EF Core', 'HTML', 'IIS', 'IT SKILLS', 'IT services', 'MVC', 'MVC 4', 'MVC4', 'MVC5', 'Model', 'Operating Systems', 'Operating Systems : Windows', 'Oracle 10', 'RESTful services', 'SDLC', 'SQL Server', 'SQL Server 2008', 'SQL Server 2012', 'SVN', 'Software Development Lifecycle', 'System Integration Testing', 'TFS', 'UI', 'Visual Studio', 'Web APIs', 'administrative tasks', 'agile', 'bug fixes', 'code base', 'code coverage', 'code reviews', 'communications', 'communications services', 'data warehouses', 'effective communicator', 'front end', 'health care', 'innovative', 'organizational capabilities', 'process optimisation', 'requirement analysis', 'technical design', 'unit test', 'xUnit']
#
#
#  ASHISH CHANDRA KESHARWANI
#
# ['API', 'Agile', 'Application server Tomcat', 'C', 'Design Patterns', 'Intellij', 'J2EE', 'J2EE technologies', 'JPA', 'Java Technologies', 'JavaSE', 'Kotlin', 'MVC', 'Maven', 'OJB', 'Oracle Mysql', 'Oriented Programming', 'Postgres', 'SDLC', 'Scrum', 'Server side', 'Server side Programming', 'Spring web MVC', 'Supply Chain', 'Tomcat', 'UI', 'Web Servers', 'business application', 'enterprise application', 'enterprise application development', 'finished good', 'good communication', 'in memory database', 'motivated', 'postgres', 'self motivated', 'web services']
#
#
#  PRINCE JOSE
#
# ['API', 'API Integration', 'API development', 'ASP', 'ASP .Net', 'AWS', 'Agile', 'Agile Development', 'Angular', 'Angular 2', 'Angular 6', 'Angular 7', 'B2B', 'Big Query', 'CSS', 'CSS3', 'Database Designing', 'Docker', 'ERP', 'ES6', 'Google BigQuery', 'HTML', 'HTML5', 'Json', 'Kafka', 'Keycloak', 'LMS', 'Learning Management Systems', 'Model', 'Mongo', 'Mongo dB', 'NodeJs', 'PROJECTS HANDLED', 'Requirement Analysis', 'SCRUM', 'SDLC', 'SSO', 'SVN', 'Self paced learning', 'Server side', 'Version Control tools', 'Zend', 'classroom training', 'database designing', 'eLearning', 'front end', 'management application', 'pos', 'technical standards', 'understand the requirements', 'version management']
#
#
#  Alla Narasimha Murthy
#
# ['.Net 4.5', '.Net Framework', 'API', 'Agile', 'Artificial Neural Networks', 'BRMS', 'C', 'CI', 'CSS', 'Core Java', 'Data structures', 'Design Pattern', 'Html', 'JSON', 'Linq', 'MVC', 'MVC5', 'Management Application', 'Model', 'MySQL Server', 'Neural Networks', 'QA', 'RDBMS', 'SCRUM', 'SQL Server', 'SQL server', 'SSIS', 'SSIS Packages', 'SSIS packages', 'Software services', 'TECHNICAL SKILLS', 'TFS', 'UI', 'business requirements', 'new technologies', 'predict', 'validate data']
#
#
#  KARUNAGARAN VISWANATHAN
#
# ['Account maintenance', 'Accounting System', 'Accounting system', 'Active Reports', 'BMC Remedy', 'Balance Sheet', 'Balance reports', 'Bug fixes', 'Business Solutions', 'C', 'Clear Case', 'Crystal Report', 'DB2', 'Database : SQL', 'Design and development', 'ERP', 'Finance & Accounting', 'Finance Accounting', 'Financial Accounting System', 'Human Resource', 'IDS', 'MVC', 'Materials Management', 'Membership management', 'Oracle 10', 'Oracle 8i', 'POS', 'SOAP', 'SQL Server', 'SQL Server 2005', 'SQL Server 2008', 'SSIS', 'Sql Server', 'Sql Server 2005', 'Tally', 'VB', 'VB 6.0', 'VB.NET', 'VB.Net', 'VB.net', 'Web Services', 'balance reports', 'business solution', 'client interaction', 'corrective actions', 'efficient handling', 'excel', 'manage personnel', 'result oriented', 'understand the requirements', 'unit test']
#
#
#  KANIKA GARG
#
# ['B2B', 'CSS', 'Core Java', 'ESB', 'Hospital Management System', 'JDBC', 'JPA', 'JSF', 'JSP', 'MVC', 'Management System', 'SOAP', 'Webservices', 'software analysis']
#
#
#  DAMARUDHAR SURYAVANSHI
#
# ['Agile', 'Android app', 'App Server', 'Arduino', 'Azure', 'Azure cloud', 'BFSI', 'Backend Tools', 'Banking', 'Battery management', 'Bootstrap3', 'Build Tools', 'Business object', 'C', 'CI', 'CSS', 'Core Java', 'Core java', 'Cucumber', 'Database tools', 'Debian', 'Docker', 'ECOMMERCE', 'Edit plus', 'Examination', 'Examinations', 'Finance trading', 'Front end', 'HTML5', 'IOT', 'IntelliJ', 'Intellij', 'J2EE', 'JMS', 'JPA', 'JSP', 'Java EE', 'Jdbc', 'Junit 5', 'Kafka', 'Linux OS', 'Maven', 'Microsoft Azure cloud', 'My SQL', 'Nginx Server', 'NoSql Database', 'OS', 'Oracle 11', 'Quick learner', 'Redis', 'SDLC', 'SOAP', 'TDD', 'Tomcat', 'VS Code', 'VS code', 'Visual studio', 'Web logic', 'azure', 'azure iot', 'banking', 'cosmosDB', 'creative', 'ecommerce', 'innovative', 'iot', 'management Organization', 'management System', 'proxy implementation', 'software developing', 'team work']
#
#
#  SHASHANK SHEKHAR
#
# ['ADO .Net', 'API', 'ASP', 'ASP .Net', 'Activity Diagrams', 'Adaptable', 'C', 'C coding', 'CSS', 'Conceptual', 'Creative', 'Data Models', 'Defect Fixing', 'Design Patterns', 'Development Tools', 'Effective Communicator', 'Good team player', 'HTML5', 'JSON', 'LINQ', 'MSSQL', 'MSSQL Server', 'Management studio', 'Microsoft Visual', 'OOPS', 'Object Modeling', 'Optimistic', 'Presentations', 'Programming Language C', 'QA', 'Quick learner', 'SASS', 'SDLC', 'SQL Server', 'Sass', 'Server Management studio', 'Stored procedures', 'T-SQL', 'TECHNICAL SKILLS', 'UML', 'Visual Studio', 'Web Forms', 'WinForms', 'analytic skills', 'communication skills', 'development and testing', 'educational materials', 'human resource', 'motivated', 'written and oral communication skills']
#
#
#  S. VENUGOPALA
#
# ['ASP', 'ASP.Net 4.5', 'Asp', 'Asp.net 4.5', 'BI Tools', 'Business Solutions', 'C', 'CMM', 'CMS', 'CRM', 'Chain Management', 'Claim management', 'Classic ASP', 'Clinical Systems', 'Clinical systems', 'Conceptual', 'Data Analytics', 'Data Models', 'Database development', 'HTML', 'Health Care', 'LAN', 'MSBI', 'MSSQL', 'MSSQL Server', 'Microsoft Business Intelligence', 'OS', 'Object Oriented', 'Performance Appraisal Management', 'RDBMS', 'Result Oriented', 'SDLC', 'SQL Server', 'SQL Server 2005', 'SSIS', 'SSRS', 'Supply Chain', 'T-SQL', 'Technical Skills', 'WPF', 'Web Services', 'analytical skills', 'claim management', 'communication skills', 'design and development', 'development of Product', 'management system', 'model', 'motivated', 'productive', 'scheduling appointments', 'supply chain', 'test reports', 'virtual simulation', 'web services', 'windows OS']
#
#
#  DHANYASHREE K V
#
# ['.Net framework', 'Angular', 'Angular JS', 'Azure', 'C', 'CSS', 'Determined', 'Excellent communication', 'Excellent communication skills', 'HTML', 'Logical skills', 'TECHNICAL SKILLS', 'communication skills', 'developing web', 'developing web applications', 'network', 'web applications']
#
#
#  Muralikrishna G S
#
# ['API', 'Android OS', 'Android SDK', 'Application Lifecycle', 'Core Java', 'Data store', 'Design and Development', 'Good communication', 'Google APIs', 'HDFS', 'HIVE', 'Hadoop', 'Hive', 'JSON', 'Kotlin', 'Mobile App', 'OS', 'POS', 'REST services', 'SVN', 'SVN version control', 'Scrum', 'TFS', 'Technical Skills', 'UI', 'Windows 2008', 'client requirement', 'communication skills', 'design principles', 'design team', 'new technologies', 'requirement gathering', 'scrum', 'view', 'web services', 'work under pressure']
#
#
#  Mamata Mathapat
#
# ['API', 'API development', 'APM', 'ASP', 'ASP.NET Web API 2', 'ASP.Net MVC 4.0', 'ASP.Net MVC 5', 'Agile', 'Agile Development', 'Agile Development Environment', 'Agile methodologies', 'Agile methodology', 'Angular.js', 'Backbone JS', 'BackboneJS', 'C', 'C# 4.0', 'CMS', 'Confluence', 'Defect Fixing', 'Dotnet', 'HTML5', 'JSON', 'Knockout.js', 'LINQ', 'MS SQL', 'MS SQL server', 'MVC', 'Management Software', 'Management System', 'Microsoft Visual', 'Microsoft Visual Studio 2017', 'Restful Services', 'SCRUM', 'SDLC', 'SQL server', 'SVN', 'Source Control', 'TDD', 'TFS', 'Tortoise SVN', 'UAT', 'Visual Studio', 'Visual Studio 2013', 'Visual Studio 2017', 'Visual studio', 'Web API 2', 'azure', 'capital market', 'client service', 'company policies', 'decision support', 'defect fixing', 'design and development', 'model', 'rest API', 'user stories', 'view']
#
#
#  SUBRAHMANYA MAIYA
#
# ['Angular', 'Angular 8', 'App Development', 'CSS', 'Database Systems', 'HTML', 'Hybrid Mobile App', 'Ionic framework', 'Listening', 'Mobile App', 'Mobile App Development', 'Operating Systems', 'Operating Systems : Windows', 'Personal Skills', 'Programming Languages', 'Quick learner', 'Technical Skills', 'hybrid mobile application', 'learning new technologies', 'new technologies', 'programming languages', 'technical skills']
#
#
#  Sairindhri Bhattacharya
#
# ['API', 'Agile', 'Angular', 'Angular 7', 'CSS', 'CSS 3', 'Collaborating', 'Core Competencies', 'Core Java', 'Design & Development', 'Development Lifecycle', 'Examination', 'HANA', 'HANA studio', 'HTML', 'HTML5', 'Innovator', 'J2EE', 'JPA', 'Java 7', 'Java8', 'Planning', 'Quality Testing', 'REST API', 'Relationship Management', 'Requirement Gathering', 'Rest API', 'SAP', 'SAP HANA studio', 'SDLC', 'SQL Queries', 'Software Development Lifecycle', 'Spring Rest', 'Springboot', 'Technical Design', 'Technical Skills', 'UAT', 'Web Project', 'business requirements', 'communicating', 'compiling reports', 'customer requirements', 'data implementation', 'effective communicator', 'examination', 'relationship management', 'requirement analysis', 'requirement gathering', 'result oriented', 'software application', 'software systems', 'technical design', 'technical requirements', 'test plans', 'test scripts', 'use cases', 'view']
#
#
#  Sandil Kumar S
#
# ['.Net 3.5', '.Net 3.5 framework', '.Net 4.5', '.Net 4.5 framework', 'AI', 'API', 'Agile', 'Agile Methodologies', 'Angular', 'Angular 5', 'Angular JS', 'Api', 'C', 'Collaborative', 'Collaborative Teaching', 'Database Connectivity', 'Education Management', 'Examination', 'HTML5', 'Highly motivated', 'Html5', 'IIS', 'IIS 7.0', 'Information Technology', 'Linq', 'MIS', 'MIS reports', 'MSSQL', 'MVC', 'Management Module', 'Management System', 'Msmq', 'Net Framework', 'Odata', 'Oracle 10', 'Oracle 9I', 'Oracle 9i', 'Payment Management', 'RDBMS', 'Reporting application', 'SDLC', 'SQL Server', 'SSRS', 'TFS', 'VB.Net', 'VB.net', 'WCF', 'Web Technologies', 'Windows Server 2008', 'api', 'client requirement', 'communication skills', 'ecommerce', 'generating reports', 'good team player', 'learn quickly', 'motivated', 'perform testing', 'self Learner', 'solving skills', 'stored procedures', 'technical aptitude', 'work collaboratively']
#
#
#  Mahesh T. S
#
# ['.NET Frame work', '.NET Framework', '.Net framework', '2003 server', 'API', 'ASP', 'ASP 3.0', 'ASP coding', 'Angular', 'Angular JS', 'C', 'DB2', 'Database : SQL', 'Database conversion', 'Determined', 'Development and Maintenance', 'Dot net', 'Dotnet', 'E-Commerce', 'ERP', 'Excel', 'Front End', 'GSAP', 'GUI', 'HTML', 'Internet Information Server', 'Internet Information server', 'Inventory Maintenance', 'Java Script', 'Lab research', 'Laboratory analysis', 'MLM', 'MVC', 'Manage communications', 'Microsoft ASP', 'Migration Project', 'Operating Systems', 'Operating Systems : Windows', 'Oracle 11', 'Oracle 8.0', 'Oracle 9i', 'Organized testing', 'PoC', 'QIP', 'RDBMS', 'SQL DataBase', 'SQL Server', 'SQL Server 2000', 'SQL Server 2005', 'SQL Server 7.0', 'SSRS', 'Sales orders', 'Screen shot', 'Scripting languages', 'Server side', 'Server side coding', 'Sql Server', 'Technology solutions', 'Unix', 'User Acceptance', 'VB', 'VB Script', 'Visual Basic 6.0', 'WCF', 'WPF', 'Windows 2003', 'Windows 2003 server', 'agile', 'communications', 'confluence', 'design patterns', 'developing web', 'development and testing', 'effective Team Player', 'excel', 'fast learner', 'friendly', 'full Life Cycle', 'functional and technical design', 'health care', 'inventory maintenance', 'legacy systems', 'manage the data', 'message queue', 'model', 'network', 'new technologies', 'quality checking', 'rdbms', 'reporting tool', 'requirement gathering', 'server side', 'stored procedures', 'technical design', 'user interfaces', 'user stories', 'view', 'web based software', 'web services']
#
#
#  Shivam Thukral
#
# ['Angular', 'CSS', 'Design Patterns', 'HTML5', 'Hibernate Framework', 'J2EE', 'J2EE Technologies', 'JDBC', 'JPA', 'JSP', 'Java Script', 'MVC', 'MVC Architecture', 'Management System', 'Maven', 'RDMS', 'Rest WebServices', 'Server : Apache Tomcat', 'Service Interfaces', 'Tomcat', 'Visual Studio', 'Web Server : Tomcat', 'Web Services', 'WebServices', 'Windows 10', 'company management', 'level management', 'model', 'sales report', 'technical ability', 'technical skills', 'view', 'web based application']
#
#
#  JITENDRA KUMAR
#
# ['API', 'AWS', 'Agile', 'C', 'CSS', 'DBMS', 'Data Analytics', 'Frontend Development', 'HTML', 'Information Systems', 'JSON', 'JavaScript frameworks', 'MVC', 'NodeJS', 'NodeJs', 'RESTful APIs', 'React.js', 'Web Designing', 'Web Technologies', 'friendly']
#
#
#  Nivas D M
#
# ['.Net Framework', '.net MVC', 'AES', 'C', 'CSS', 'Code development', 'Complaint Management', 'Development and maintenance', 'ERP', 'HTML', 'IIS', 'Json', 'Linq', 'MANAGEMENT INFORMATION', 'MIS', 'MVC', 'Maintained database', 'Operating Systems', 'Programming Languages', 'SQL Server', 'SQL Server 2012', 'SQL server', 'Stored procedures', 'Technical Skills', 'Visual Studio', 'Visual Studio 2015', 'Visual Studio 2017', 'api', 'design and development', 'developing web', 'developing web applications', 'development of Web application', 'requirement gathering', 'sql queries', 'status reports', 'web applications']
#
#
#  Gireesh S. Javali
#
# ['.NET Framework', '2003 server', 'ASP.NET 2.0', 'ASP.NET 3.5', 'Access 2000', 'Agile', 'Agile methodology', 'App Server', 'Azure', 'C', 'CSS', 'Crystal Reports', 'Crystal Reports 8.5', 'ERP', 'HTML', 'Html', 'IIS', 'IIS 6.0', 'MVC', 'Microsoft .NET', 'Microsoft .NET Framework', 'Oracle 10', 'Reporting tool', 'SQL 2008', 'SQL Server', 'SQL Server 2008', 'SQL Server 2012', 'SSRS', 'SVN', 'TFS', 'Technical Skills', 'Testing of applications', 'UI', 'UI development', 'VB.Net', 'Version Control Tools', 'Visual Studio', 'Web Technologies', 'Windows 10', 'Windows 2003', 'Windows 2003 server', 'Windows server 2012', 'client requirement', 'code reviews', 'deployment of code', 'maintenance and support', 'unit test']
#
#
#  DAVID BABU M
#
# ['AIX', 'API', 'AS400', 'AWS', 'Agile', 'Agile Methodology', 'Apache Lucene framework', 'Apache httpd', 'Application Servers', 'C', 'CMVC', 'Chain Management', 'ClearCase', 'ClearQuest', 'Client virtualization', 'Cloud Front', 'Cloud Platform', 'CloudWatch', 'Cost Planning', 'Customer Relationship', 'DB2', 'Design Evaluation', 'Development Tools', 'EC2', 'EJB', 'ESB', 'Enterprise Application', 'Hadoop', 'Hibernate 3.0', 'IBM Rational Software', 'IBM Rational Software Architect', 'IBM Smart Cloud', 'IBM Tivoli', 'IBM Tivoli Provisioning Manager', 'IBM WebSphere Application', 'IDS', 'J2EE', 'J2EE 1.4', 'JBoss', 'JDBC', 'JDK', 'JDK 1.4', 'JDK 1.5', 'JMS', 'JSF', 'JSON', 'JSP', 'JSTL', 'Jasper', 'Java Development', 'LDAP', 'Lucene', 'Lucene framework', 'Maven', 'Microsoft VSS', 'Model', 'MySQL 5.0', 'MySQL Server', 'Operating Systems', 'Operating Systems : Windows', 'Oracle 8i', 'People Leadership', 'Planning', 'Process methodology', 'RDBMS', 'RUP', 'Rational AppScan', 'Rational Rose', 'Rational Software', 'Rational Software Architect', 'Red Hat', 'Red Hat Linux', 'SAMBA', 'SAML', 'SAML 2.0', 'SAP', 'SDLC', 'SOA', 'SOA architecture', 'SQLServer', 'SSL', 'SVN', 'SaaS', 'SaaS product', 'Schedule Planning', 'Scrum', 'Solr', 'Struts', 'Struts 1.1', 'Supply Chain', 'TECHNICAL SKILLS', 'TOMCAT', 'Tivoli Monitoring', 'Toad', 'Tomcat', 'Tortoise SVN', 'UML', 'VSS', 'Visio', 'VisualAge', 'WAS 6.1', 'WSAD', 'WSDL', 'Web Services', 'WebServices', 'WebSphere', 'WebSphere Application Server', 'XML SPY', 'XSL', 'agile', 'agile process', 'agile process framework', 'analysis of business', 'application performance', 'auto scaling', 'business solutions', 'capture requirements', 'communication networks', 'design sessions', 'development team', 'distributed systems', 'framework API', 'jmeter', 'management software', 'management tools', 'micro services', 'planning', 'presentations', 'product strategy', 'product strategy and roadmap', 'quality metrics', 'rendering', 'requirements gathering', 'scrum', 'supply chain', 'system development', 'technical design', 'technical documents', 'use cases', 'user stories']
#
#
#  Naveen B
#
# ['API', 'Activity Diagrams', 'Agile', 'Agile methodology', 'Android SDK', 'Android app', 'Api', 'Flutter', 'Good communication', 'JSON', 'Objective c', 'Responsive Design', 'Restful services', 'UI', 'UI Development', 'Use Case Diagrams', 'View', 'agile', 'analysing', 'c', 'ecommerce', 'examination', 'flexibility', 'flutter', 'mobile app', 'model', 'model making', 'view']
#
#
#  AKHILESH H N
#
# ['ANGULAR', 'BANKING', 'CSS', 'Eclipse IDE', 'Examination', 'Examinations', 'Flexibility', 'HTML', 'OS', 'Quick Learner', 'TECHNICAL SKILLS', 'Visual Studio', 'WINDOWS OS']
#
#
#  N. PRASANNAKUMAR
#
# ['API', 'Android SDK', 'Android Sdk', 'Angular', 'Angular 4', 'Angular js', 'Api', 'Application Maintenance & Support', 'Asp', 'C', 'Databases : Microsoft SQL Server', 'Front End', 'Html5', 'Hybrid Mobile Application', 'Hybrid Mobile Application Development', 'IOS Development', 'IT SKILLS', 'Ionic 3', 'Ionic Framework', 'JSON', 'Listening', 'MS Sql', 'MS Sql Server', 'Microsoft SQL', 'Microsoft Visual', 'Microsoft Visual studio 2015', 'Mobile Application Development frameworks', 'Mobile Development', 'Mobile Development Frameworks', 'My Sql', 'Networking', 'Operating Systems', 'Operating Systems : Windows', 'POSTMAN Tool', 'Programming Languages', 'SOAP', 'SQL Server', 'Sql Server', 'Visual studio', 'Visual studio 2015', 'Windows Platforms', 'Windows Server 2012', 'Word Press', 'analysing', 'best practices', 'business requirements', 'customer information', 'design specifications', 'effective communicator', 'friendly', 'functional requirements', 'implementing solutions', 'information systems', 'information systems management', 'management processes', 'motivated', 'phonegap', 'resolve problems', 'self motivated', 'stock management', 'system design', 'working with clients']
#
#
#  Ramnath K
#
# ['C', 'CSS', 'Full Stack Web Development', 'HTML', 'Visual studio', 'front end', 'management system', 'modern technologies', 'mongo', 'mongo db']
#
#
#  HARIHARAN M
#
# ['AI', 'COMPUTER VISION', 'Excel', 'Image Classification', 'Image Processing', 'ML', 'MS Office', 'Microsoft Power BI', 'Plotly', 'R Programming', 'R Studio', 'Tableau', 'UI', 'nltk', 'plotly', 'predict']
#
#
#  M Shamanth Morae
#
# ['C', 'C++ programming', 'Excel', 'JAVA programming', 'Listening', 'Listening Skills', 'Network', 'Network intrusion detection', 'PYTHON PROGRAMMING', 'PowerPoint', 'Presentation skills', 'VSS', 'collaborative', 'intrusion detection', 'motivated', 'network', 'networking']
#
#
#  Syed Self
#
# ['Angular', 'Angular 8', 'Azure', 'CSS3', 'Css3', 'Html5', 'IIS', 'IIS server', 'Listening', 'NodeJS', 'Red Hat', 'manage website', 'motivated', 'view', 'website development']
#
#
#  JYOTHIKA B
#
# ['Communication skills', 'Flexibility', 'Front end', 'INNOVATIVE', 'IOT', 'MODEL', 'Microsoft visual', 'Microsoft visual basic', 'Microsoft visual basic 6.0', 'development Program', 'visual basic 6.0']
#
#
#  Divya Garg
#
# ['API', 'Agile', 'Bit Bucket', 'Build Tools', 'CSS', 'Eclipse IDE', 'HTML', 'J2EE', 'JPA', 'Java J2EE', 'Management Tools', 'Maven', 'ORM', 'ORM Tools', 'Oracle SQL', 'SVN', 'Scrum', 'Subversion', 'Technical Skills', 'Tortoise SVN', 'Version Management', 'Web services', 'business rules', 'micro services', 'view', 'web services']
#
#
#  KUMAR
#
# ['API', 'AWS', 'CSS', 'CSS3', 'Ci', 'ES6', 'HTML', 'HTML5', 'Innovative', 'JSON', 'Listening', 'MEAN Stack', 'NODEJS', 'Node JS', 'Nodejs', 'OPEN SOURCE', 'OPERATING SYSTEMS', 'REST API', 'React JS', 'SASS', 'SDLC', 'SDLC METHODOLOGIES', 'Sass', 'WEB TECHNOLOGIES', 'build tools', 'business solution', 'development teams', 'management software', 'office management software', 'planning', 'react JS', 'view']
#
#
#  Purendra Naik
#
# ['.Net framework', 'API', 'Agile', 'Application performance', 'Asp.net 2.0', 'C', 'C# 4.0', 'CORE COMPETENCIES', 'CSS', 'Design and Development', 'Development Processes', 'E-commerce', 'GUI', 'HTML', 'Html', 'IIS', 'IIS 7.0', 'Java Script', 'LINQ', 'MS SQL', 'MS SQL Server', 'MS SQL Server 2008', 'MS SQL Server 2008 R2', 'MSMQ', 'MVC', 'Model', 'OOPS', 'OpenSpan', 'SQL Server', 'SQL Server 2008', 'SQL Server 2008 R2', 'SQL Server Development', 'Scrum', 'Server 2008 R2', 'Software Development Processes', 'TFS', 'Team collaboration', 'Team foundation server', 'Unit test', 'User stories', 'VB', 'VB6', 'Visual Basic 6', 'Visual Studio', 'WCF', 'Web Forms', 'Web Services', 'Web forms', 'Web services', 'Windows 2008', 'best practices', 'commercial real estate', 'dot net', 'e-commerce', 'friendly', 'html', 'management software', 'productive', 'records management software', 'refactoring code', 'requirement gathering', 'software application', 'streamline processes', 'team building skills', 'unit test', 'user interfaces', 'view', 'windows services']
#
#
#  PLABAN YOTI BEHERA
#
# ['API', 'API Integration', 'Accounting Management', 'Android Application Development', 'Android SDK', 'Complaint Management', 'Computer Science Engineering', 'Design Application', 'Google Map', 'Google Map API', 'JSON', 'Kotlin', 'MVC', 'MVP', 'PROJECTS HANDLED', 'Programming Language : Java', 'Property Administration', 'Service Provider Management', 'UI', 'dedicated', 'mobile app']
#
#
#  T. Lakshmi Prathyusha
#
# ['.NET Technologies', '.Net framework', '.Net framework 4.0', 'ASP.NET 3.5', 'CSS3', 'Capacity Planning', 'Crystal Reports', 'ERP', 'ERP System', 'ERP system', 'Excel', 'FDs', 'FusionCharts', 'HTML', 'HTML5', 'Information Management', 'JSON', 'Java Script', 'MVC', 'Management System', 'Microsoft .NET', 'Microsoft .NET Technologies', 'Microsystems', 'Operating Systems', 'Operation & Maintenance', 'POC', 'Planning', 'Programming Languages', 'RDLC', 'Requirements gathering', 'SDLC', 'SQL Server', 'SQL Server 2008', 'SQL Server 2012', 'Sdn', 'Test Case', 'Trade Processing', 'UAT', 'Unit Test', 'VB.NET', 'Vb', 'Web Technologies', 'c', 'defect fixing', 'design and development', 'front end', 'full life cycle', 'planning', 'process improvements', 'project implementation', 'vb.net']
#
#
#  Avinash Babu Balaboyina
#
# ['Angular', 'Angular 10', 'Angular 2', 'Angular js', 'Angular.js', 'Backbone js', 'Bootstrap framework', 'CSS', 'CSS3', 'CSS3 style sheets', 'Css3', 'DHTML', 'Flutter', 'Front End', 'Front-end development', 'Gather requirements', 'HTML', 'HTML5', 'Html5', 'IIS', 'Innovative', 'Internet Applications', 'J2EE', 'J2EE technologies', 'J2ee', 'JSP', 'Java Server Pages', 'JavaScript libraries', 'Nodejs', 'Photoshop', 'React.js', 'Responsible for designing', 'Rich Internet Applications', 'SQL Server', 'Twitter Bootstrap', 'UI', 'Ui', 'XHTML', 'Xhtml', 'angular', 'angular js', 'best practices', 'computer Science Engineering', 'css3', 'development skills', 'feasibility study', 'java script', 'motivated', 'test-driven development', 'web designing']
#
#
#  Vedant Patwardhan
#
# ['Angular', 'Angular 8', 'Azure', 'Azure Cloud', 'Azure Cloud Computing', 'Business application', 'CSS', 'Communication Skills', 'Devexpress', 'Front end', 'Good Communication', 'HTML', 'Image Processing', 'Java Script', 'Leadership skills', 'Quick Learner', 'TECHNICAL SKILLS', 'WPF']
#
#
#  KUMAR New Delhi
#
# ['ANGULAR', 'AWS', 'BUSINESS to BUSINESS', 'C', 'CLOUD FOUNDRY', 'CMS', 'CSS', 'CSS3', 'CYBER SECURITY', 'EC2', 'ECOMMERCE', 'Examination', 'HTML', 'HTML5', 'PIVOTAL CLOUD', 'PIVOTAL CLOUD FOUNDRY', 'PIVOTAL CLOUD FOUNDRY PLATFORM', 'SOAP', 'TECHNICAL SKILLS', 'WEB SERVICES']

# %% [markdown]
# # Luhn Summarization

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.luhn import LuhnSummarizer

# %%
def clean_(summary):
    stop_words = nltk.corpus.stopwords.words('english')
    return [w for w in gensim.utils.simple_preprocess(str(summary)) if w not in stop_words]

# %%
sum_corpus = []
summary_dict = []  
for id_ in data:
    text = data[id_]['ResumeParserData']["DetailResume"]
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    
    summarizer_luhn = LuhnSummarizer()
    summary =summarizer_luhn(parser.document,5)  #Summarizes to 5 Sentences

    summary_dict.append({"fileID": id_, "summary": clean_(summary)})

srsly.write_jsonl("E:\\Arpitha Swamydas\\Ev Project\\summary file.jsonl", summary_dict)

# %%
sumFile = list(srsly.read_jsonl("E:\\Arpitha Swamydas\\Ev Project\\summary file.jsonl"))

# %% [markdown]
# # Word2Vec

# %%
sentences = [i['summary'] for i in sumFile]  #reading all the sentences from the file

# %%
#Vocab Creation on corpus
model = Word2Vec(sentences=sentences, vector_size=300, window=5, min_count=1, workers=4)
#corpus = model.wv.vectors #vectors of all summary

# %%
# Out:
# 8250

# %%
model.wv.vectors.shape, all_vec.shape
# Out:
# ((2273, 300), (64, 300))

# %%
for i in sumFile:
    i["docVec"] = model.wv[i['summary']].mean(axis=0)

# %%
all_vec = np.array([i['docVec'] for i in sumFile])
def most_sim(vec):
    i = (-model.wv.cosine_similarities(vec, all_vec)).argsort()[1:6]
    return [sumFile[j]['fileID'] for j in i]

# %%
print(data['0']["ResumeParserData"]["DetailResume"])
# Out:
# Prasanth Kumar Katta
# Phone No : 8790296753
# Email Id : kpcode4u@gmail.com
#
# Profile Summary
#
# 	  Udacity Certified Co-Created With Google - Android Developer Nanodegree Graduate.
# 	  Having 3.7+ year of Experience in developing Client/Server Applications using Java in developing Mobile
# 	  Applications using Android Technologies.
# 	  Good Experience on Jet Pack Libraries (Architecture components like Room, LiveData and View Model,
# 	  Navigation Components and Binding Views .etc)
# 	  Worked as one of Coordinator cum Trainer in Google Code Lab.
# 	  Strong Programming Skills in Java, Android and Firebase.
# 	  Worked as one of the Self Learning Coordinator Lead in APSSDC.
# 	  Good knowledge on developing Android applications by using Eclipse and Android Studio.
# 	  Good experience in working with XML and UI.
# 	  Good experience Google API Console, Android Architecture Components, Firebase and Sockets.
# 	  Strong hands on experience in Google maps (GPS) , version control tools like git and bitbucket.
# 	  Good Experience in API integration using AsyncTask, Retrofit, Volley and Async Http libraries.
# 	  Excellent interpersonal and organizational skills, Quick learner, adaptable and process-oriented with a high
#  customer orientation.
#
# Technical Skills
#
# Languages : Java, Android and Kotlin.
# GUI : Html, XML
# Tools/IDEs : Eclipse, My Eclipse, Android Studio and Visual Studio
# Web Services : Google API Console
# Data Bases Known : Room Database (SQLite) and Firebase
# GitHub Link : https://github.com/PrasanthKumarKatta
# Certifications : https://confirm.udacity.com/F53VJ6GD
#
# Working Experience
#
# 	  Worked from Jan to March with Mobile Programming India Pvt Ltd as a Software Developer.
# 	  Worked 7 months with Primor Consultancy Services Pvt Ltd as Android Developer.
# 	  Worked 2.8 year with Andhra Pradesh State Skill Development Corporation (APSSDC) as Android Developer.
#
# Projects Undertaken
#
# Project : Brentwood Carpool
# Team Size : 2
# Environment : Java, Kotlin, Android and Firebase
# Role : Team Member, Worked on Chat and Push notifications using Firebase.
# Description :
#
# 	  School carpool ride app between parent and student.
# 	  Google Directions, Calls, push notifications and Chat between ride Users.
# Roles and Responsibilities
# 	  Developed Chat and Push notifications accordingly Android vs IOS and Android Version based requirements.
# Project : Whats Happening (Device Management Services look like in WhatsApp)
# Team Size : 2
# Environment : Core Java, Android, Dashboard in BirdView
# Role : Team Member, Worked on BirdView dash Board and some other Important modules.
# Description :
# 	  Available to see Team Member List and BirdView are two main Modules.
# 	  Geo Tracking, Battery, Signal Strength, Tab ON/OFF, Calls, SMS and Time Lines
# Roles and Responsibilities
# 	  Developed Activities accordingly to requirements look like Whats App.
# 	  Implemented BirdView based on the requirement of App
# 	  Co-ordination with the team using Bitbucket
# 	  Working as module lead for Enhancements
#
# Project : View Box (able to play Videos like YouTube, displaying Documents, PDFs, Audios)
# Team Size : 2
# Environment : Core Java, Android, Dashboard to add Videos, Audios, Documents
# Role : Team Member
# Description :
# 	  Available add Videos, Documents, Audios.etc. in Dashboard.
# 	  With hierarchy based displaying and UI look like YouTube.
#
# Project : Agri Aiuto (Multiple Language Database support (crop, merchant and pesticides) , weather report and expert
# Chat Box Functionality)
# Team Size : 2
# Environment : Core Java, Android and Third Party Library.
# Role : Team Lead
# Description :
# 	  Available in Multiple Languages of Firebase Real Time such as Database Crop, Merchants and Pesticides Details.
# 	  Chat Box Also there for discussing about Any issues or user able to comment for any crop photo, then expert gives proper explanation/suggestions.
# 	  Firebase Authentication, Real Time Database, Notification Services Used.
# 	  Weather API Integration Also Added for displaying daily weather report.
# 	  Handle error cases in Android.
# 	  Add a widget to your app experience.
# 	  Use Fragments to create a responsive design that works on phones and tablets.
# Project : Movie Star (Multiple Language Movie App with Chat Functionality)
# Team Size : 1
# Environment : Core Java, Android and Third Party Library.
# Play Store Link : Movie Star Google Play Store
#
# Role : Team Lead
# Description :
# 	  Displays Multiple Languages Movie Details such as Rating, Trailers, Posters, Rating and Crew.
# 	  Chat Box Also there for discussing about Movie or meet other users as text based group chat.
# 	  Firebase Authentication, Real Time Database, Notification Services Used.
# 	  YouTube Integration Also Added for displaying trailers.
# 	  Handle error cases in Android.
# 	  Add a widget to your app experience.
# 	  Used Retrofit third-party library.
# 	  Use Fragments to create a responsive design that works on phones and tablets.
# Project : Baking App (Food Recipes Tutorial)
# Team Size : 2
# Environment : Core Java, Android and Third Party Library.
# Role : Team Lead
# Description :
# 	  Use Exo Player to display videos.
# 	  Handle error cases in Android.
# 	  Add a widget to your app experience.
# 	  Used Retrofit third-party library.
# 	  Use Fragments to create a responsive design that works on phones and tablets.
#
# Academics
#
# 	  B. Tech (2012-2016) from JNTUA, Andhra Pradesh attaining 62.9%. From Siddharth Institute of Engineering &
# Technology, Chittoor (Dt) , A.P.

# %%
print(data['46']["ResumeParserData"]["DetailResume"])
# Out:
# JITENDRA KUMAR
# #S02 Bellathur Kadugodi, Near- SBI Kadugodi Branch Whitefield Bangalore-560067	9980880469
# Ji7endra.kumar@gmail.com
#
# . Seeking a responsible job mostly in a StartUp Organization with an opportunity for professional challenges, career growth and which allows me to contribute towards achieving the organizational goals.
# . Full Stack/Web Developer with over 1 year of professional experience in Web Designing and User Interface
# Development using recent Web Technologies and frameworks.
# . Experienced in MERN Stack Developer.
# . Experienced in JavaScript frameworks and libraries like ReactJS, NodeJS.
# . Development of Applications based on approved designs.
# . Building user-friendly interfaces.
# . Knowledge of how to interact with RESTful APIs and formats (basic JSON, XML) .
# . Database Design.
# . Good understanding of Frontend Development using React.js and Backend using Node.js and MySQL/MongoDB.
#
# EXPERIENCE
#
# JULY 2019 - PRESENT
# FULLSTACK DEVELOPER, TATA CONSULTANCY SERVICES, BANGALORE
# 	  .	  Created a website with React, React hooks and context API for file management of users with a
# 	  NodeJS back-end utilizing formidable for file uploads
# 	  .	  Developed Microservice in NodeJS to interact with MongoDB.
# 	  . Database Design.
# 	  .	  Development of Applications based on approved designs.
# 	  .	  Test to ensure high-quality deliverables.
# 	  .	  Frontend Application Development Using HTML, CSS, React.js, JavaScript.
# 	  .	  Learned about file management in ReactJs and NodeJs.
#
# JAN 2019 - FEB 2019
#
# LUMEN MICROFRAMEWORK-INTERNSHIP, NINESTARS, BANGALORE
# ⦁	  Created some forms and templets using HTML, CSS and JavaScript.
# ⦁ MVC understanding.
# ⦁	  Built Boarding pass &Invoice templets & wrote code which helps in Boarding & Invoice templets will be downloaded automatically in pdf & jpg format with users' details after users book ticket on StellarJet.
# ⦁	  Creating simple database using MySQL and testing using Postman application.
#
# SKILLS
# .	  React.JS 	 .	  Node.JS 	 . Express
# .	  MongoDB 	 .	  JavaScript 	 . HTML
# .	  CSS 	 .	  Python 	 . Django
# .	  PHP 	 .	  CodeIgniter 	 . MySQL
# .	  JSON 	 . AWS
#
# Training Undertaken
# Title	  Certificate name Date
# CodeIgniter LinkedinLearning Jan-21
# Full Stack Developer (MERN) Udemy Jan-21
# DBMS	  IIT Bombay Spoken Tutorial Nov-18
# PHP & MySQL	  IIT Bombay Spoken Tutorial Nov-17
# Python	  IIT Bombay Spoken Tutorial May-18
# C	  IIT Bombay Spoken Tutorial Nov-16
# C++	  IIT Bombay Spoken Tutorial Nov-16
# Java	  IIT Bombay Spoken Tutorial May-17
# Data Analytics Workshop
# NIT Tiruchirappalli (NITT) at
# Pragyan Mar-18
#
# ACADEMIC QUALIFICATIONS
# Degree/
# Certification	  Degree Discipline Institute
# Board/
# University
# Year of
# Passing
# Aggregate
#  (CGPA/%)
# Graduation B.E.
# Computer
# Science and
# Engineering
# MVJ College
#  of
# Engineering,
# Bangalore
# Visvesvaraya
# Technological
# University
#  (VTU) 2015-2019	  CGPA - 8.03
# 12th AISSCE Science
# Private
# Candidates CBSE 2014-2015	79.60%
# 12th AISSCE Science
# Academy
# Rahmatpur
# Asarganj
# Munger
# Bihar	  K N Memo CBSE 2013-2014	62.40%
# 10th	  AISSCE Arya Bal
# Shanti
# Niketan
# Maulsairi
# Talle
# Munger
# Bihar	  CBSE	  2011-2012	  CGPA - 9.2
#
# 2
#
# ACHIEVEMENTS
# .	  Honour Award in Highest Scholastic Co-operation.
# .	  Certificate for presenting the paper titled Study and Analysis Of Susceptibility of Micro-bacterium
# 	  Tuberculosis using Machine Learning at the 2nd International Conference on Innovations in
# 	  Computing, Automation & Intelligent Information Systems (ICAIIS-2019) .
# .	  Certificate for participated in the event Agile organized by NIC Club.
#
# PERSONAL INFORMATION
# 	  .	  DATE OF BIRTH : - 19TH MARCH 1995
# 	  .	  NATIONALITY : - INDIAN
# 	  .	  LANGUAGE KNOWN : - ENGLISH, HINDI, MAITHILI
# 	  .	  PASSPORT : - APPLIED
# 	  .	  PERMANENT ADDRESS : - FAUJDARI BAZAAR, P.S. - KASIM BAZAAR, P.O. - MUNGER, DISTRICT/CITY
# 	  - MUNGER, STATE - BIHAR, PIN CODE - 811201
#
# PERSONAL Detail :
#
# Place : Bengaluru
# Date : Signature
#
# 3
#
# Annotations :
# mailto : Ji7endra.kumar@gmail.com

# %%
most_sim(sumFile[0]['docVec'])
# Out:
# ['14', '9', '45', '20', '47']

# %%
for i in sumFile:
    i['most_similar'] = most_sim(i['docVec'])

# %%
sumFile[0]['most_similar']
# Out:
# ['14', '9', '45', '20', '47']

# %%
sumFile[0]
# Out:
# {'fileID': '0',
#  'summary': ['sentence',
#   'project',
#   'brentwood',
#   'carpool',
#   'team',
#   'size',
#   'environment',
#   'java',
#   'kotlin',
#   'android',
#   'firebase',
#   'role',
#   'team',
#   'member',
#   'worked',
#   'chat',
#   'push',
#   'notifications',
#   'using',
#   'firebase',
#   'sentence',
#   'project',
#   'view',
#   'box',
#   'able',
#   'play',
#   'videos',
#   'like',
#   'youtube',
#   'displaying',
#   'documents',
#   'pdfs',
#   'audios',
#   'team',
#   'size',
#   'environment',
#   'core',
#   'java',
#   'android',
#   'dashboard',
#   'add',
#   'videos',
#   'audios',
#   'documents',
#   'role',
#   'team',
#   'member',
#   'description',
#   'available',
#   'add',
#   'videos',
#   'documents',
#   'audios',
#   'etc',
#   'sentence',
#   'project',
#   'agri',
#   'aiuto',
#   'multiple',
#   'language',
#   'database',
#   'support',
#   'crop',
#   'merchant',
#   'pesticides',
#   'weather',
#   'report',
#   'expert',
#   'chat',
#   'box',
#   'functionality',
#   'team',
#   'size',
#   'environment',
#   'core',
#   'java',
#   'android',
#   'third',
#   'party',
#   'library',
#   'sentence',
#   'role',
#   'team',
#   'lead',
#   'description',
#   'available',
#   'multiple',
#   'languages',
#   'firebase',
#   'real',
#   'time',
#   'database',
#   'crop',
#   'merchants',
#   'pesticides',
#   'details',
#   'sentence',
#   'project',
#   'movie',
#   'star',
#   'multiple',
#   'language',
#   'movie',
#   'app',
#   'chat',
#   'functionality',
#   'team',
#   'size',
#   'environment',
#   'core',
#   'java',
#   'android',
#   'third',
#   'party',
#   'library'],
#  'docVec': array([-5.29076380e-04,  3.08387470e-03,  1.02002465e-04,  1.42456510e-03,
#          1.35738388e-04, -3.26735084e-03,  2.00286275e-03,  6.18389435e-03,
#          3.25091649e-04, -9.80230281e-04, -2.78918305e-04, -2.60727853e-03,
#          1.91591709e-04, -7.74153217e-04, -2.07134546e-03, -2.04776344e-03,
#          1.26020075e-03, -4.35149414e-04,  7.69035541e-04, -1.20773888e-03,
#         -1.44512055e-03,  7.75404114e-05,  2.38764472e-03,  2.21371913e-04,
#          2.83521321e-03,  1.98688838e-04, -2.74370867e-03,  3.38744896e-04,
#         -1.64026476e-03, -1.32998370e-03,  7.17034098e-04, -6.72461407e-04,
#          5.16554050e-04, -2.87201285e-04, -1.40763470e-03,  2.07014833e-04,
#          1.10858207e-04, -3.54267447e-03, -1.04607642e-03, -4.21635719e-04,
#         -2.03451142e-03,  5.11730090e-04, -3.51880386e-04, -2.23314343e-03,
#          1.53790729e-03,  2.13055592e-03,  9.63427185e-04,  1.03270169e-03,
#         -1.02816604e-03,  3.56708909e-03,  5.25305048e-04,  8.23602721e-04,
#         -1.23326911e-03,  5.18062850e-04, -5.12969389e-04,  2.30523408e-03,
#          1.07257708e-03,  7.21909339e-04,  3.81324848e-04,  7.62694981e-04,
#         -1.22691307e-03, -1.40132976e-03, -2.21389404e-04,  3.08821065e-04,
#          1.94225606e-04,  6.94231479e-04,  4.72329033e-04,  2.62304791e-04,
#         -1.67058979e-03, -1.59699901e-03, -2.33561135e-04,  1.90551509e-03,
#          2.62407283e-03, -2.69868458e-03, -9.83164413e-04,  1.59644848e-03,
#         -2.06218916e-03, -1.08955828e-04, -6.04286673e-04,  1.96255464e-03,
#         -1.46782328e-03, -2.13689147e-03,  8.09943827e-04,  4.28327592e-03,
#          2.23863899e-04,  8.80399894e-04, -1.27902906e-03, -1.21054582e-04,
#          2.46869167e-03,  5.01307368e-04,  2.93125981e-03, -1.64018734e-03,
#          1.78717030e-03,  4.34402173e-04,  3.02017503e-03,  2.84223817e-03,
#          2.57801032e-03, -1.09153939e-03, -1.48277532e-03,  2.33072322e-03,
#         -8.89718067e-04,  1.33665904e-04,  2.02601147e-03,  7.73027306e-04,
#          1.24979345e-03, -1.89673691e-03, -1.12136058e-03,  7.63575081e-04,
#         -3.06465779e-03,  1.38119014e-03, -2.95736291e-03, -1.46897475e-03,
#         -7.63518154e-04,  2.43273936e-03,  1.43181789e-03,  1.56907004e-03,
#         -2.53978389e-04, -3.79266450e-04,  3.23697925e-03, -2.58120708e-03,
#          1.71006040e-03,  6.56097021e-04,  1.43133337e-03, -6.16070640e-04,
#         -1.28074025e-03,  1.23697869e-03,  8.79380677e-04, -2.82041566e-03,
#          2.02541603e-04,  1.32928335e-03,  9.04372719e-04,  3.18202097e-03,
#          4.20652155e-04, -2.59438157e-03,  2.22914433e-03,  1.09395350e-03,
#         -7.60231807e-04, -1.07388408e-03, -1.48966920e-03, -2.78521562e-03,
#          9.17980156e-04, -3.20925168e-03, -2.81194050e-04,  1.48281618e-03,
#          1.12744432e-03, -9.99541488e-04, -3.79499258e-03, -8.34217644e-04,
#          1.28873065e-03, -1.22331281e-03,  2.78753607e-04, -3.81949870e-03,
#         -1.69841468e-03, -9.49572248e-04, -2.70058663e-04,  1.42689713e-03,
#         -2.22877972e-03, -1.32313068e-03, -4.90879116e-04,  3.48194805e-03,
#          9.13620170e-04,  1.75142474e-03, -2.93585239e-03,  1.95112440e-03,
#         -1.45637512e-03,  5.57976833e-04,  1.32051995e-03, -4.13696805e-04,
#          1.73234625e-03,  3.96894384e-03, -8.56764964e-04, -6.77396951e-04,
#          7.79820373e-04,  8.06785771e-04, -4.17262083e-04, -9.30206210e-04,
#          5.76756836e-04, -2.16164114e-03, -2.35881904e-04, -1.41792654e-04,
#         -1.70354336e-03,  1.43585110e-03, -1.45970902e-03, -2.05562869e-03,
#         -5.54274477e-04,  1.89718918e-07,  3.27834068e-03,  2.24344409e-03,
#          1.52304466e-03, -2.52817711e-03, -1.32583693e-04, -6.08803130e-05,
#         -3.00904014e-03,  5.52152924e-04,  8.60295375e-04, -1.42902974e-03,
#          7.62755808e-04, -2.58322246e-03,  1.31351838e-03,  1.29387062e-03,
#         -2.03463784e-03,  1.22243713e-03, -6.32771698e-04, -1.25012652e-03,
#         -7.62199561e-05, -6.47476059e-04, -8.83026107e-04,  9.96880699e-04,
#          4.05703759e-04, -5.48486481e-04,  4.94842359e-04, -2.65009678e-03,
#         -1.07171596e-03, -1.62626908e-03,  4.61805495e-04, -2.78371526e-03,
#         -1.02889305e-03, -4.07726085e-03, -3.49183427e-03, -2.55283108e-03,
#          1.52457319e-03,  5.44775568e-04, -1.26627786e-03, -2.06721039e-03,
#         -1.66953891e-03, -1.55149156e-03,  5.69477794e-04, -7.36986054e-04,
#         -2.52378080e-03,  3.09981144e-04,  1.79156428e-03, -7.71093415e-04,
#         -1.91177381e-03,  2.05297139e-03, -1.49829709e-03, -1.51323242e-04,
#          4.20933124e-04,  5.63750451e-04,  1.52264640e-03, -4.19406919e-03,
#         -1.28360654e-04, -1.10586907e-03, -1.67516677e-03,  7.85301556e-04,
#          2.86596041e-04, -1.99700170e-03, -6.09862560e-04,  1.01513334e-03,
#         -4.85750235e-04,  2.14984245e-03,  7.09935499e-04,  8.98738916e-04,
#          6.81231613e-04, -7.20006879e-04, -2.90446752e-03, -2.79686158e-03,
#          3.34975589e-03,  6.03177701e-04, -4.57376800e-03, -2.03605252e-03,
#          1.05078111e-03,  1.45722774e-03,  3.52134870e-04, -2.87837908e-03,
#         -1.91478897e-03,  5.44853829e-05,  1.04379491e-03,  1.20976346e-03,
#         -1.89143082e-03,  5.66639937e-04, -2.04378320e-03,  4.12089343e-04,
#          6.98727847e-04, -1.38755422e-03,  2.61578592e-03,  1.02175924e-03,
#          1.56209071e-03,  5.56736719e-04, -1.63506158e-03,  1.63995137e-05,
#          1.39108347e-03, -5.15376392e-04, -9.40565427e-04,  2.90341908e-04,
#          1.26073079e-04, -7.52993743e-04, -2.57102074e-03,  1.73098617e-03,
#          1.37148343e-03,  2.84388568e-03,  7.39072741e-04,  3.76284122e-03,
#          2.42673419e-03,  5.49095799e-04,  2.72693369e-03,  2.35230429e-03,
#          2.63073482e-04, -1.82123133e-03,  2.30194349e-03,  6.12033764e-05],
#        dtype=float32),
#  'most_similar': ['14', '9', '45', '20', '47']}

# %% [markdown]
# # KNN

# %%
#Model building for all_vec array
nbrs = NearestNeighbors(n_neighbors=6).fit(all_vec)

# %%
#nbrs.kneighbors_graph(all_vec).toarray()

# %%
nbrs.kneighbors(X = sumFile[0]['docVec'].reshape(1, -1))
# Out:
# (array([[4.65661287e-10, 5.81214322e-03, 5.98599543e-03, 6.06947736e-03,
#          6.08471658e-03, 6.14214179e-03]]),
#  array([[ 0, 27, 17, 30, 31, 14]], dtype=int64))

# %%
map_table = {p:q for p, q in enumerate([i['fileID'] for i in sumFile])}
def knn_similar(vec):
    distances, indices = nbrs.kneighbors(X = vec)
    #print(list(sumFile[j]['fileID'] for j in indices[:, 1:].flatten()))
    return [map_table[j] for j in indices[:, 1:].flatten()]

# %%
knn_similar(sumFile[-1]['docVec'].reshape(1, -1))
# Out:
# ['42', '35', '24', '12', '7']

# %%
#for i in sumFile:
    #i['knn_similar'] = knn_similar(i['docVec'])

# %%
for i in sumFile:
    i['knn_similar'] = knn_similar(i['docVec'].reshape(1, -1))

# %%
print(sumFile[0]['most_similar'])
print(sumFile[0]['knn_similar'])
# Out:
# ['14', '9', '45', '20', '47']
# ['28', '18', '31', '32', '15']

# %%
print(sumFile[13]['most_similar'])
print(sumFile[13]['knn_similar'])
# Out:
# ['28', '20', '42', '47', '35']
# ['47', '36', '45', '20', '26']

# %%
sumFile[0]
# Out:
# {'fileID': '0',
#  'summary': ['sentence',
#   'project',
#   'brentwood',
#   'carpool',
#   'team',
#   'size',
#   'environment',
#   'java',
#   'kotlin',
#   'android',
#   'firebase',
#   'role',
#   'team',
#   'member',
#   'worked',
#   'chat',
#   'push',
#   'notifications',
#   'using',
#   'firebase',
#   'sentence',
#   'project',
#   'view',
#   'box',
#   'able',
#   'play',
#   'videos',
#   'like',
#   'youtube',
#   'displaying',
#   'documents',
#   'pdfs',
#   'audios',
#   'team',
#   'size',
#   'environment',
#   'core',
#   'java',
#   'android',
#   'dashboard',
#   'add',
#   'videos',
#   'audios',
#   'documents',
#   'role',
#   'team',
#   'member',
#   'description',
#   'available',
#   'add',
#   'videos',
#   'documents',
#   'audios',
#   'etc',
#   'sentence',
#   'project',
#   'agri',
#   'aiuto',
#   'multiple',
#   'language',
#   'database',
#   'support',
#   'crop',
#   'merchant',
#   'pesticides',
#   'weather',
#   'report',
#   'expert',
#   'chat',
#   'box',
#   'functionality',
#   'team',
#   'size',
#   'environment',
#   'core',
#   'java',
#   'android',
#   'third',
#   'party',
#   'library',
#   'sentence',
#   'role',
#   'team',
#   'lead',
#   'description',
#   'available',
#   'multiple',
#   'languages',
#   'firebase',
#   'real',
#   'time',
#   'database',
#   'crop',
#   'merchants',
#   'pesticides',
#   'details',
#   'sentence',
#   'project',
#   'movie',
#   'star',
#   'multiple',
#   'language',
#   'movie',
#   'app',
#   'chat',
#   'functionality',
#   'team',
#   'size',
#   'environment',
#   'core',
#   'java',
#   'android',
#   'third',
#   'party',
#   'library'],
#  'docVec': array([-5.29076380e-04,  3.08387470e-03,  1.02002465e-04,  1.42456510e-03,
#          1.35738388e-04, -3.26735084e-03,  2.00286275e-03,  6.18389435e-03,
#          3.25091649e-04, -9.80230281e-04, -2.78918305e-04, -2.60727853e-03,
#          1.91591709e-04, -7.74153217e-04, -2.07134546e-03, -2.04776344e-03,
#          1.26020075e-03, -4.35149414e-04,  7.69035541e-04, -1.20773888e-03,
#         -1.44512055e-03,  7.75404114e-05,  2.38764472e-03,  2.21371913e-04,
#          2.83521321e-03,  1.98688838e-04, -2.74370867e-03,  3.38744896e-04,
#         -1.64026476e-03, -1.32998370e-03,  7.17034098e-04, -6.72461407e-04,
#          5.16554050e-04, -2.87201285e-04, -1.40763470e-03,  2.07014833e-04,
#          1.10858207e-04, -3.54267447e-03, -1.04607642e-03, -4.21635719e-04,
#         -2.03451142e-03,  5.11730090e-04, -3.51880386e-04, -2.23314343e-03,
#          1.53790729e-03,  2.13055592e-03,  9.63427185e-04,  1.03270169e-03,
#         -1.02816604e-03,  3.56708909e-03,  5.25305048e-04,  8.23602721e-04,
#         -1.23326911e-03,  5.18062850e-04, -5.12969389e-04,  2.30523408e-03,
#          1.07257708e-03,  7.21909339e-04,  3.81324848e-04,  7.62694981e-04,
#         -1.22691307e-03, -1.40132976e-03, -2.21389404e-04,  3.08821065e-04,
#          1.94225606e-04,  6.94231479e-04,  4.72329033e-04,  2.62304791e-04,
#         -1.67058979e-03, -1.59699901e-03, -2.33561135e-04,  1.90551509e-03,
#          2.62407283e-03, -2.69868458e-03, -9.83164413e-04,  1.59644848e-03,
#         -2.06218916e-03, -1.08955828e-04, -6.04286673e-04,  1.96255464e-03,
#         -1.46782328e-03, -2.13689147e-03,  8.09943827e-04,  4.28327592e-03,
#          2.23863899e-04,  8.80399894e-04, -1.27902906e-03, -1.21054582e-04,
#          2.46869167e-03,  5.01307368e-04,  2.93125981e-03, -1.64018734e-03,
#          1.78717030e-03,  4.34402173e-04,  3.02017503e-03,  2.84223817e-03,
#          2.57801032e-03, -1.09153939e-03, -1.48277532e-03,  2.33072322e-03,
#         -8.89718067e-04,  1.33665904e-04,  2.02601147e-03,  7.73027306e-04,
#          1.24979345e-03, -1.89673691e-03, -1.12136058e-03,  7.63575081e-04,
#         -3.06465779e-03,  1.38119014e-03, -2.95736291e-03, -1.46897475e-03,
#         -7.63518154e-04,  2.43273936e-03,  1.43181789e-03,  1.56907004e-03,
#         -2.53978389e-04, -3.79266450e-04,  3.23697925e-03, -2.58120708e-03,
#          1.71006040e-03,  6.56097021e-04,  1.43133337e-03, -6.16070640e-04,
#         -1.28074025e-03,  1.23697869e-03,  8.79380677e-04, -2.82041566e-03,
#          2.02541603e-04,  1.32928335e-03,  9.04372719e-04,  3.18202097e-03,
#          4.20652155e-04, -2.59438157e-03,  2.22914433e-03,  1.09395350e-03,
#         -7.60231807e-04, -1.07388408e-03, -1.48966920e-03, -2.78521562e-03,
#          9.17980156e-04, -3.20925168e-03, -2.81194050e-04,  1.48281618e-03,
#          1.12744432e-03, -9.99541488e-04, -3.79499258e-03, -8.34217644e-04,
#          1.28873065e-03, -1.22331281e-03,  2.78753607e-04, -3.81949870e-03,
#         -1.69841468e-03, -9.49572248e-04, -2.70058663e-04,  1.42689713e-03,
#         -2.22877972e-03, -1.32313068e-03, -4.90879116e-04,  3.48194805e-03,
#          9.13620170e-04,  1.75142474e-03, -2.93585239e-03,  1.95112440e-03,
#         -1.45637512e-03,  5.57976833e-04,  1.32051995e-03, -4.13696805e-04,
#          1.73234625e-03,  3.96894384e-03, -8.56764964e-04, -6.77396951e-04,
#          7.79820373e-04,  8.06785771e-04, -4.17262083e-04, -9.30206210e-04,
#          5.76756836e-04, -2.16164114e-03, -2.35881904e-04, -1.41792654e-04,
#         -1.70354336e-03,  1.43585110e-03, -1.45970902e-03, -2.05562869e-03,
#         -5.54274477e-04,  1.89718918e-07,  3.27834068e-03,  2.24344409e-03,
#          1.52304466e-03, -2.52817711e-03, -1.32583693e-04, -6.08803130e-05,
#         -3.00904014e-03,  5.52152924e-04,  8.60295375e-04, -1.42902974e-03,
#          7.62755808e-04, -2.58322246e-03,  1.31351838e-03,  1.29387062e-03,
#         -2.03463784e-03,  1.22243713e-03, -6.32771698e-04, -1.25012652e-03,
#         -7.62199561e-05, -6.47476059e-04, -8.83026107e-04,  9.96880699e-04,
#          4.05703759e-04, -5.48486481e-04,  4.94842359e-04, -2.65009678e-03,
#         -1.07171596e-03, -1.62626908e-03,  4.61805495e-04, -2.78371526e-03,
#         -1.02889305e-03, -4.07726085e-03, -3.49183427e-03, -2.55283108e-03,
#          1.52457319e-03,  5.44775568e-04, -1.26627786e-03, -2.06721039e-03,
#         -1.66953891e-03, -1.55149156e-03,  5.69477794e-04, -7.36986054e-04,
#         -2.52378080e-03,  3.09981144e-04,  1.79156428e-03, -7.71093415e-04,
#         -1.91177381e-03,  2.05297139e-03, -1.49829709e-03, -1.51323242e-04,
#          4.20933124e-04,  5.63750451e-04,  1.52264640e-03, -4.19406919e-03,
#         -1.28360654e-04, -1.10586907e-03, -1.67516677e-03,  7.85301556e-04,
#          2.86596041e-04, -1.99700170e-03, -6.09862560e-04,  1.01513334e-03,
#         -4.85750235e-04,  2.14984245e-03,  7.09935499e-04,  8.98738916e-04,
#          6.81231613e-04, -7.20006879e-04, -2.90446752e-03, -2.79686158e-03,
#          3.34975589e-03,  6.03177701e-04, -4.57376800e-03, -2.03605252e-03,
#          1.05078111e-03,  1.45722774e-03,  3.52134870e-04, -2.87837908e-03,
#         -1.91478897e-03,  5.44853829e-05,  1.04379491e-03,  1.20976346e-03,
#         -1.89143082e-03,  5.66639937e-04, -2.04378320e-03,  4.12089343e-04,
#          6.98727847e-04, -1.38755422e-03,  2.61578592e-03,  1.02175924e-03,
#          1.56209071e-03,  5.56736719e-04, -1.63506158e-03,  1.63995137e-05,
#          1.39108347e-03, -5.15376392e-04, -9.40565427e-04,  2.90341908e-04,
#          1.26073079e-04, -7.52993743e-04, -2.57102074e-03,  1.73098617e-03,
#          1.37148343e-03,  2.84388568e-03,  7.39072741e-04,  3.76284122e-03,
#          2.42673419e-03,  5.49095799e-04,  2.72693369e-03,  2.35230429e-03,
#          2.63073482e-04, -1.82123133e-03,  2.30194349e-03,  6.12033764e-05],
#        dtype=float32),
#  'most_similar': ['14', '9', '45', '20', '47'],
#  'knn_similar': ['28', '18', '31', '32', '15']}
